# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as pl

mice_eeg1 = pd.read_csv('./pw3_data/EEG_mouse_data_1.csv')
mice_eeg2 = pd.read_csv('./pw3_data/EEG_mouse_data_2.csv')
mice_eeg = pd.concat([mice_eeg1, mice_eeg2], axis=0)

# Select the first 25 amplitudes as they are the most interesting
mice_eeg = mice_eeg.iloc[:, :26]

# %%
import keras
from keras import layers
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler

output_data = []  # Assuming this is available and aligned with mice_eeg

pl.clf()
keras.utils.set_random_seed(123)
kf = KFold(n_splits=3, shuffle=True)

for i, (train_index, test_index) in enumerate(kf.split(mice_eeg)):
    scaler = StandardScaler()
    # Select the training and test data
    train_data = mice_eeg.iloc[train_index]
    test_data = mice_eeg.iloc[test_index]
    train_numeric_columns = train_data.columns[1:]

    # Fit the scaler on the training data and transform both training and test data
    train_numeric_values = scaler.fit_transform(train_data.loc[:, train_numeric_columns])
    test_numeric_values = scaler.transform(test_data.loc[:, train_numeric_columns])

    # Update the transformed data in the DataFrames
    train_data.loc[:, train_numeric_columns] = train_numeric_values
    test_data.loc[:, train_numeric_columns] = test_numeric_values

    # Now you can print the transformed train_data
    print(train_data)
# Out:
# 2024-03-22 10:19:42.289859: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
#       state  amplitude_around_1_Hertz  amplitude_around_2_Hertz  \
# 0         n                 -0.208032                 -0.084971
# 2         n                 -0.143098                  3.647342
# 3         w                 -0.435617                  0.935007
# 4         w                 -0.186212                 -0.240048
# 5         w                  0.012680                 -0.162101
# ...     ...                       ...                       ...
# 20600     w                  0.387854                 -0.465343
# 20601     w                  0.082683                  1.379755
# 20602     w                  0.064987                  0.791565
# 20603     w                 -0.064123                 -0.088293
# 20604     w                 -0.422924                 -0.545588
#
#        amplitude_around_3_Hertz  amplitude_around_4_Hertz  \
# 0                     -0.106292                 -0.028809
# 2                      1.390951                  0.313159
# 3                      2.072013                  0.138299
# 4                     -0.178842                  0.175915
# 5                     -0.112565                  1.111152
# ...                         ...                       ...
# 20600                 -0.526768                 -0.804548
# 20601                  0.016194                 -0.266535
# 20602                  1.185504                 -0.230088
# 20603                  0.375385                  0.231141
# 20604                 -0.248271                  0.762706
#
#        amplitude_around_5_Hertz  amplitude_around_6_Hertz  \
# 0                      0.820109                 -0.239420
# 2                      0.038470                 -0.562062
# 3                     -0.509365                 -0.570936
# 4                      0.572452                  0.715405
# 5                      0.292493                  2.846819
# ...                         ...                       ...
# 20600                 -0.631364                 -0.982307
# 20601                  0.475099                 -0.577720
# 20602                  0.479758                 -1.031573
# 20603                 -0.480916                  0.234977
# 20604                  2.197637                 -0.396976
#
#        amplitude_around_7_Hertz  amplitude_around_8_Hertz  \
# 0                      0.673836                 -0.123322
# 2                     -0.181074                 -0.750274
# 3                     -0.641067                 -0.470288
# 4                      0.228871                  1.197077
# 5                      1.430858                  1.600277
# ...                         ...                       ...
# 20600                 -0.664367                 -0.166093
# 20601                 -0.153974                  0.007359
# 20602                  0.262647                 -0.925127
# 20603                 -0.259518                  0.557830
# 20604                 -0.592859                  0.824782
#
#        amplitude_around_9_Hertz  ...  amplitude_around_16_Hertz  \
# 0                      0.708423  ...                  -0.327978
# 2                     -0.458002  ...                   0.445242
# 3                     -0.466525  ...                   0.408051
# 4                      0.828215  ...                   1.183525
# 5                     -0.108292  ...                   0.554391
# ...                         ...  ...                        ...
# 20600                  0.302818  ...                  -0.574822
# 20601                 -0.079113  ...                  -0.776293
# 20602                 -0.298382  ...                  -0.429698
# 20603                 -0.597675  ...                  -0.604511
# 20604                  0.096172  ...                   0.164935
#
#        amplitude_around_17_Hertz  amplitude_around_18_Hertz  \
# 0                      -0.360341                  -0.430512
# 2                       1.638235                  -0.109866
# 3                      -0.469844                  -0.619500
# 4                       1.368756                   2.334500
# 5                      -0.074441                   1.928321
# ...                          ...                        ...
# 20600                  -0.674217                   0.785159
# 20601                  -0.763861                   0.154416
# 20602                  -0.687656                  -0.342426
# 20603                   0.376146                  -0.688562
# 20604                   0.940323                  -0.393087
#
#        amplitude_around_19_Hertz  amplitude_around_20_Hertz  \
# 0                       1.118898                   1.496344
# 2                      -0.315102                  -0.184698
# 3                      -0.842123                  -0.859343
# 4                       0.867954                  -0.212317
# 5                       0.359062                   0.034247
# ...                          ...                        ...
# 20600                  -0.058779                  -0.188639
# 20601                   0.516882                   1.351549
# 20602                  -0.180565                  -0.304024
# 20603                  -0.669021                  -0.456797
# 20604                   0.162912                  -0.455681
#
#        amplitude_around_21_Hertz  amplitude_around_22_Hertz  \
# 0                       0.044517                   1.051764
# 2                      -0.282123                  -0.596955
# 3                      -0.644023                  -0.401343
# 4                       1.139440                   2.054265
# 5                       0.737767                   0.798484
# ...                          ...                        ...
# 20600                   0.443347                   0.916696
# 20601                   0.175078                   0.735786
# 20602                  -1.142366                   0.023695
# 20603                  -0.699222                  -0.819487
# 20604                  -0.702869                   0.532300
#
#        amplitude_around_23_Hertz  amplitude_around_24_Hertz  \
# 0                       1.019389                   2.323721
# 2                      -0.805498                  -0.646213
# 3                      -0.864946                   0.414493
# 4                       0.383296                  -0.142897
# 5                       0.900887                  -0.282329
# ...                          ...                        ...
# 20600                   0.726912                  -0.479607
# 20601                   0.018573                   0.836182
# 20602                  -1.163554                  -1.152556
# 20603                   0.107342                  -0.092147
# 20604                   5.353869                   0.040905
#
#        amplitude_around_25_Hertz
# 0                      -0.663249
# 2                      -0.897154
# 3                      -0.228533
# 4                       0.429535
# 5                      -0.473735
# ...                          ...
# 20600                  -0.415109
# 20601                   0.894740
# 20602                  -0.942187
# 20603                   0.638431
# 20604                   1.439669
#
# [27242 rows x 26 columns]
#       state  amplitude_around_1_Hertz  amplitude_around_2_Hertz  \
# 0         n                 -0.221629                 -0.078106
# 1         n                 -0.193433                 -0.323318
# 4         w                 -0.197848                 -0.235475
# 6         w                 -0.412031                 -0.108850
# 8         w                 -0.115488                  0.987902
# ...     ...                       ...                       ...
# 20598     w                  0.216908                 -0.041879
# 20599     w                 -0.006927                  0.034861
# 20601     w                  0.095216                  1.408269
# 20602     w                  0.075929                  0.811386
# 20604     w                 -0.455837                 -0.545530
#
#        amplitude_around_3_Hertz  amplitude_around_4_Hertz  \
# 0                     -0.102006                 -0.024118
# 1                     -0.227977                  0.071865
# 4                     -0.174793                  0.181060
# 6                      2.198362                 -0.219731
# 8                      0.670595                  0.208178
# ...                         ...                       ...
# 20598                  0.277196                 -0.197524
# 20599                 -0.269450                 -0.403183
# 20601                  0.020882                 -0.262370
# 20602                  1.194028                 -0.225843
# 20604                 -0.244450                  0.769149
#
#        amplitude_around_5_Hertz  amplitude_around_6_Hertz  \
# 0                      0.819265                 -0.241578
# 1                      0.741471                  0.552838
# 4                      0.571530                  0.722906
# 6                     -0.169711                 -0.519785
# 8                      2.850082                  4.222621
# ...                         ...                       ...
# 20598                 -0.293501                 -0.450042
# 20599                 -0.283675                 -0.568135
# 20601                  0.474147                 -0.583300
# 20602                  0.478807                 -1.041746
# 20604                  2.197223                 -0.400728
#
#        amplitude_around_7_Hertz  amplitude_around_8_Hertz  \
# 0                      0.673364                 -0.126737
# 1                      1.398873                 -0.099671
# 4                      0.230272                  1.183055
# 6                     -0.436275                 -0.391573
# 8                      4.039566                  2.894425
# ...                         ...                       ...
# 20598                 -0.202875                 -0.778269
# 20599                 -0.774156                  0.717179
# 20601                 -0.150962                  0.002894
# 20602                  0.263906                 -0.922102
# 20604                 -0.588000                  0.813751
#
#        amplitude_around_9_Hertz  ...  amplitude_around_16_Hertz  \
# 0                      0.703973  ...                  -0.325857
# 1                      0.095350  ...                  -0.262748
# 4                      0.823536  ...                   1.175184
# 6                     -0.010696  ...                   0.483166
# 8                      2.221303  ...                   0.914139
# ...                         ...  ...                        ...
# 20598                 -0.963866  ...                  -0.746209
# 20599                 -0.653378  ...                  -0.886658
# 20601                 -0.082061  ...                  -0.771070
# 20602                 -0.300912  ...                  -0.426874
# 20604                  0.092890  ...                   0.163644
#
#        amplitude_around_17_Hertz  amplitude_around_18_Hertz  \
# 0                      -0.360375                  -0.433901
# 1                       0.892134                   0.866984
# 4                       1.348857                   2.313110
# 6                      -0.125443                   0.195831
# 8                       2.232861                  -0.140382
# ...                          ...                        ...
# 20598                   0.096139                  -1.029209
# 20599                  -0.715450                  -0.870115
# 20601                  -0.759260                   0.147219
# 20602                  -0.683930                  -0.346389
# 20604                   0.925345                  -0.396720
#
#        amplitude_around_19_Hertz  amplitude_around_20_Hertz  \
# 0                       1.145250                   1.486561
# 1                      -0.826261                   0.210499
# 4                       0.891243                  -0.213928
# 6                       0.954843                  -0.467683
# 8                       2.403892                   3.885899
# ...                          ...                        ...
# 20598                  -1.048209                  -0.135046
# 20599                   1.013845                   0.335811
# 20601                   0.535887                   1.342458
# 20602                  -0.170071                  -0.305196
# 20604                   0.177598                  -0.456128
#
#        amplitude_around_21_Hertz  amplitude_around_22_Hertz  \
# 0                       0.045556                   1.042248
# 1                       1.463028                   0.228427
# 4                       1.147026                   2.035282
# 6                      -0.050533                  -0.455099
# 8                       0.628231                   0.222128
# ...                          ...                        ...
# 20598                  -0.428421                   1.076835
# 20599                   0.281933                  -0.438127
# 20601                   0.176897                   0.729253
# 20602                  -1.148424                   0.023887
# 20604                  -0.706300                   0.527689
#
#        amplitude_around_23_Hertz  amplitude_around_24_Hertz  \
# 0                       1.014062                   2.295941
# 1                       0.249482                  -0.833920
# 4                       0.380637                  -0.145798
# 6                      -0.420981                   0.065915
# 8                       0.283689                  -0.576653
# ...                          ...                        ...
# 20598                  -0.242591                  -0.654210
# 20599                  -0.216758                  -0.072820
# 20601                   0.017443                   0.823406
# 20602                  -1.159726                  -1.145274
# 20604                   5.330361                   0.036150
#
#        amplitude_around_25_Hertz
# 0                      -0.665833
# 1                       0.356892
# 4                       0.435257
# 6                      -0.785655
# 8                      -0.062216
# ...                          ...
# 20598                  -0.775875
# 20599                  -1.256052
# 20601                   0.903998
# 20602                  -0.946891
# 20604                   1.453068
#
# [27242 rows x 26 columns]
#       state  amplitude_around_1_Hertz  amplitude_around_2_Hertz  \
# 1         n                 -0.176044                 -0.327450
# 2         n                 -0.137229                  3.694720
# 3         w                 -0.427893                  0.949477
# 5         w                  0.017562                 -0.160943
# 7         w                  0.223119                  0.357805
# ...     ...                       ...                       ...
# 20597     w                 -0.493749                  0.007843
# 20598     w                  0.198069                 -0.046745
# 20599     w                 -0.006004                  0.029795
# 20600     w                  0.390358                 -0.467864
# 20603     w                 -0.058754                 -0.086239
#
#        amplitude_around_3_Hertz  amplitude_around_4_Hertz  \
# 1                     -0.231717                  0.066301
# 2                      1.379614                  0.315621
# 3                      2.055863                  0.138544
# 5                     -0.113273                  1.123736
# 7                     -0.661594                  1.721388
# ...                         ...                       ...
# 20597                 -0.267573                  1.972773
# 20598                  0.268245                 -0.205902
# 20599                 -0.272762                 -0.413710
# 20600                 -0.524548                 -0.816262
# 20603                  0.371227                  0.232563
#
#        amplitude_around_5_Hertz  amplitude_around_6_Hertz  \
# 1                      0.737351                  0.562037
# 2                      0.034430                 -0.564325
# 3                     -0.512668                 -0.573338
# 5                      0.288111                  2.897606
# 7                     -0.360342                 -0.466798
# ...                         ...                       ...
# 20597                  2.409878                 -0.628078
# 20598                 -0.295904                 -0.446250
# 20599                 -0.286095                 -0.564980
# 20600                 -0.634502                 -0.991111
# 20603                 -0.484257                  0.245118
#
#        amplitude_around_7_Hertz  amplitude_around_8_Hertz  \
# 1                      1.376469                 -0.105012
# 2                     -0.182328                 -0.748384
# 3                     -0.635150                 -0.473048
# 5                      1.404472                  1.563130
# 7                      2.930021                  0.271352
# ...                         ...                       ...
# 20597                 -0.472695                  0.170680
# 20598                 -0.206971                 -0.777743
# 20599                 -0.771721                  0.704778
# 20600                 -0.658086                 -0.173904
# 20603                 -0.259549                  0.537996
#
#        amplitude_around_9_Hertz  ...  amplitude_around_16_Hertz  \
# 1                      0.104098  ...                  -0.263064
# 2                     -0.454020  ...                   0.448135
# 3                     -0.462566  ...                   0.410864
# 5                     -0.103381  ...                   0.557518
# 7                     -0.518327  ...                  -0.798639
# ...                         ...  ...                        ...
# 20597                 -0.836236  ...                  -0.598493
# 20598                 -0.959962  ...                  -0.750942
# 20599                 -0.648055  ...                  -0.892675
# 20600                  0.308821  ...                  -0.574125
# 20603                 -0.594064  ...                  -0.603878
#
#        amplitude_around_17_Hertz  amplitude_around_18_Hertz  \
# 1                       0.881520                   0.878422
# 2                       1.592670                  -0.104033
# 3                      -0.456736                  -0.610414
# 5                      -0.072338                   1.921147
# 7                      -0.606939                  -0.127734
# ...                          ...                        ...
# 20597                  -0.144486                  -0.272950
# 20598                   0.098686                  -1.018017
# 20599                  -0.699484                  -0.858902
# 20600                  -0.655421                   0.785281
# 20603                   0.365708                  -0.679036
#
#        amplitude_around_19_Hertz  amplitude_around_20_Hertz  \
# 1                      -0.826207                   0.223918
# 2                      -0.302507                  -0.175632
# 3                      -0.839744                  -0.851462
# 5                       0.384725                   0.043699
# 7                      -0.705557                   0.916310
# ...                          ...                        ...
# 20597                  -0.688305                  -0.400974
# 20598                  -1.049729                  -0.123899
# 20599                   1.026952                   0.350053
# 20600                  -0.041216                  -0.179580
# 20603                  -0.663286                  -0.448209
#
#        amplitude_around_21_Hertz  amplitude_around_22_Hertz  \
# 1                       1.454347                   0.230312
# 2                      -0.277038                  -0.586990
# 3                      -0.638042                  -0.393704
# 5                       0.740324                   0.791852
# 7                      -0.860519                  -1.031076
# ...                          ...                        ...
# 20597                  -0.626913                  -0.567571
# 20598                  -0.421200                   1.076620
# 20599                   0.283181                  -0.434592
# 20600                   0.446633                   0.908658
# 20603                  -0.693104                  -0.806874
#
#        amplitude_around_23_Hertz  amplitude_around_24_Hertz  \
# 1                       0.252744                  -0.836570
# 2                      -0.805543                  -0.645947
# 3                      -0.865058                   0.408160
# 5                       0.902779                  -0.284327
# 7                      -0.117570                  -0.682007
# ...                          ...                        ...
# 20597                   0.134012                  -0.603690
# 20598                  -0.241962                  -0.656159
# 20599                  -0.215991                  -0.072499
# 20600                   0.728605                  -0.480378
# 20603                   0.108333                  -0.095328
#
#        amplitude_around_25_Hertz
# 1                       0.344953
# 2                      -0.890186
# 3                      -0.228941
# 5                      -0.471438
# 7                       1.804604
# ...                          ...
# 20597                  -1.084385
# 20598                  -0.766869
# 20599                  -1.238167
# 20600                  -0.413459
# 20603                   0.628460
#
# [27242 rows x 26 columns]

# %%
def create_model():
    # 2 inputs
    # 2 hidden nodes
    # 1 output
    mlp = keras.Sequential([
        layers.Input(25),
        layers.Dense(32, activation="tanh"),  # Try different numbers of hidden neurons here (e.g. 2, 4, 8, 32, 128)
        layers.Dense(32, activation="tanh"),
    ])

    # Experiment with hyperparameters here:
    # momentum: [0, 0.8, 0.9, 0.99]
    # learning_rate: [0.1, 0.01, 0.001, 0.0001]
    mlp.compile(
        optimizer=keras.optimizers.SGD(learning_rate=0.01, momentum=0.99),
        loss="mse",
    )

    return mlp

mlp = create_model()
mlp.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 32)                832
#
#  dense_1 (Dense)             (None, 32)                1056
#
# =================================================================
# Total params: 1,888
# Trainable params: 1,888
# Non-trainable params: 0
# _________________________________________________________________
# 2024-03-22 10:19:45.465002: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.

# %%
history_list = []
trained_mlp = []

for i, (train_index, test_index) in enumerate(kf.split(mice_eeg)):
    # We need to create a new model every time, otherwise fit will continue previous training
    mlp = create_model()
    history = mlp.fit(
        x=mice_eeg.iloc[train_index, :25],
        y=np.array(output_data)[train_index],
        validation_data=(mice_eeg.iloc[test_index, :25], np.array(output_data)[test_index]),
        epochs=400
    )
    history_list.append(history)
    trained_mlp.append(mlp)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 9
#       4 for i, (train_index, test_index) in enumerate(kf.split(mice_eeg)):
#       5     # We need to create a new model every time, otherwise fit will continue previous training
#       6     mlp = create_model()
#       7     history = mlp.fit(
#       8         x=mice_eeg.iloc[train_index, :25],
# ----> 9         y=np.array(output_data)[train_index],
#      10         validation_data=(mice_eeg.iloc[test_index, :25], np.array(output_data)[test_index]),
#      11         epochs=400
#      12     )
#      13     history_list.append(history)
#      14     trained_mlp.append(mlp)
#
# IndexError: index 1 is out of bounds for axis 0 with size 0

# %%
train_losses = np.array([history.history['loss'] for history in history_list])
val_losses = np.array([history.history['val_loss'] for history in history_list])

# Calculate mean and standard deviation for training and validation losses
mean_train_loss = np.mean(train_losses, axis=0)
std_train_loss = np.std(train_losses, axis=0)
mean_val_loss = np.mean(val_losses, axis=0)
std_val_loss = np.std(val_losses, axis=0)

# Plot mean and standard deviation for training loss
pl.plot(mean_train_loss, label='Training Loss (Mean)')
pl.fill_between(range(len(mean_train_loss)), mean_train_loss - std_train_loss, mean_train_loss + std_train_loss, alpha=0.3, label='Training Loss (Std)')

# Plot mean and standard deviation for validation loss
pl.plot(mean_val_loss, label='Validation Loss (Mean)')
pl.fill_between(range(len(mean_val_loss)), mean_val_loss - std_val_loss, mean_val_loss + std_val_loss, alpha=0.3, label='Validation Loss (Std)')

# Add labels and legend
pl.xlabel('Epochs')
pl.ylabel('Loss')
pl.legend()

# Display the plot
pl.show()
